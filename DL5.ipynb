# %% [markdown]
# <a href="https://colab.research.google.com/github/Varshini151205/DL/blob/main/DL5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **L2 Regularization **

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers,models,regularizers

(x_train,y_train),(x_test,y_test)=mnist.load_data()

x_train=x_train.astype("float32")/255.0
x_test=x_test.astype("float32")/255.0

x_train=x_train.reshape(-1,784)
x_test=x_test.reshape(-1,784)

y_train=to_categorical(y_train,10)
y_test=to_categorical(y_test,10)

def build_l2_model():
    model=models.Sequential([
        layers.Dense(64,activation='relu',input_shape=(784,),kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(64,activation='relu',kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(10,activation='softmax')
    ])
    return model

model_l2=build_l2_model()

model_l2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history=model_l2.fit(
    x_train,
    y_train,
    epochs=10,
    validation_split=0.2,
    batch_size=32
)

test_loss,test_acc=model_l2.evaluate(x_test,y_test)

print(f"Test accuracy:{test_acc:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8175 - loss: 1.2737 - val_accuracy: 0.9179 - val_loss: 0.5481
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9181 - loss: 0.5388 - val_accuracy: 0.9333 - val_loss: 0.4717
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9254 - loss: 0.4734 - val_accuracy: 0.9298 - val_loss: 0.4433
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9323 - loss: 0.4379 - val_accuracy: 0.9423 - val_loss: 0.3993
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9361 - loss: 0.4080 - val_accuracy: 0.9342 - val_loss: 0.4104
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9402 - loss: 0.3880 - val_accuracy: 0.9463 - val_loss: 0.3649
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9436 - loss: 0.3700 - val_accuracy: 0.9530 - val_loss: 0.3381
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9469 - loss: 0.3488 - val_accuracy: 0.9448 - val_loss: 0.3531
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9481 - loss: 0.3395 - val_accuracy: 0.9426 - val_loss: 0.3508
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9497 - loss: 0.3330 - val_accuracy: 0.9529 - val_loss: 0.3179
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9406 - loss: 0.3542
# Test accuracy:0.9507

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers, models, regularizers

# Load dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Reshape
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# One-hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Modified Model
def build_l2_model():
    model = models.Sequential([
        layers.Dense(32, activation='relu',
                     input_shape=(784,),
                     kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(32, activation='relu',
                     kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(10, activation='softmax')
    ])
    return model

model_l2 = build_l2_model()

model_l2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# 🔹 Changed training settings
history = model_l2.fit(
    x_train,
    y_train,
    epochs=20,          # Increased epochs
    validation_split=0.2,
    batch_size=16       # Decreased batch size
)

# Evaluate
test_loss, test_acc = model_l2.evaluate(x_test, y_test)

print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.8210 - loss: 1.0403 - val_accuracy: 0.9113 - val_loss: 0.5638
# Epoch 2/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9133 - loss: 0.5425 - val_accuracy: 0.9352 - val_loss: 0.4610
# Epoch 3/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9248 - loss: 0.4793 - val_accuracy: 0.9293 - val_loss: 0.4451
# Epoch 4/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9271 - loss: 0.4406 - val_accuracy: 0.9377 - val_loss: 0.4000
# Epoch 5/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9319 - loss: 0.4106 - val_accuracy: 0.9369 - val_loss: 0.3968
# Epoch 6/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9331 - loss: 0.3984 - val_accuracy: 0.9417 - val_loss: 0.3688
# Epoch 7/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9360 - loss: 0.3794 - val_accuracy: 0.9414 - val_loss: 0.3645
# Epoch 8/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9360 - loss: 0.3746 - val_accuracy: 0.9491 - val_loss: 0.3360
# Epoch 9/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9403 - loss: 0.3616 - val_accuracy: 0.9455 - val_loss: 0.3382
# Epoch 10/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9389 - loss: 0.3580 - val_accuracy: 0.9399 - val_loss: 0.3436
# Epoch 11/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9411 - loss: 0.3457 - val_accuracy: 0.9500 - val_loss: 0.3276
# Epoch 12/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9414 - loss: 0.3445 - val_accuracy: 0.9480 - val_loss: 0.3278
# Epoch 13/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9462 - loss: 0.3319 - val_accuracy: 0.9441 - val_loss: 0.3316
# Epoch 14/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9468 - loss: 0.3273 - val_accuracy: 0.9499 - val_loss: 0.3185
# Epoch 15/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9459 - loss: 0.3270 - val_accuracy: 0.9520 - val_loss: 0.3164
# Epoch 16/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9464 - loss: 0.3209 - val_accuracy: 0.9436 - val_loss: 0.3314
# Epoch 17/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9466 - loss: 0.3219 - val_accuracy: 0.9542 - val_loss: 0.3076
# Epoch 18/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9456 - loss: 0.3212 - val_accuracy: 0.9446 - val_loss: 0.3189
# Epoch 19/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9463 - loss: 0.3175 - val_accuracy: 0.9519 - val_loss: 0.3018
# Epoch 20/20
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9493 - loss: 0.3095 - val_accuracy: 0.9437 - val_loss: 0.3274
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9376 - loss: 0.3533
# Test accuracy: 0.9440

# %% [markdown]
# In the 20-epoch model, training accuracy slightly increased but test accuracy slightly decreased compared to the 10-epoch model. This indicates slight overfitting due to longer training. Therefore, 10 epochs gave better generalization.

# %% [markdown]
# Changing batch size affects how frequently weights are updated. Smaller batch sizes result in more updates and noisier learning, which may improve generalization but increase training time. Larger batch sizes provide stable learning and faster training but may reduce generalization performance.

# %% [markdown]
# # **Early Stopping **

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers,models,regularizers
from tensorflow.keras.callbacks import EarlyStopping

(x_train,y_train),(x_test,y_test)=mnist.load_data()

x_train=x_train.astype("float32")/255.0
x_test=x_test.astype("float32")/255.0

x_train=x_train.reshape(-1,784)
x_test=x_test.reshape(-1,784)

y_train=to_categorical(y_train,10)
y_test=to_categorical(y_test,10)

def build_l2_model():
    model=models.Sequential([
        layers.Dense(64,activation='relu',input_shape=(784,),kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(64,activation='relu',kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(10,activation='softmax')
    ])
    return model

model_l2=build_l2_model()

model_l2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

earlystop = EarlyStopping(
    monitor='val_accuracy',
    patience=3,
    restore_best_weights=True
)



history=model_l2.fit(
    x_train,
    y_train,
    epochs=10,
    validation_split=0.2,
    batch_size=32,
    callbacks=[earlystop]
)

test_loss,test_acc=model_l2.evaluate(x_test,y_test)

print(f"Test accuracy:{test_acc:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8358 - loss: 1.2605 - val_accuracy: 0.9173 - val_loss: 0.5554
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9178 - loss: 0.5420 - val_accuracy: 0.9347 - val_loss: 0.4634
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9312 - loss: 0.4639 - val_accuracy: 0.9400 - val_loss: 0.4326
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9378 - loss: 0.4253 - val_accuracy: 0.9420 - val_loss: 0.4085
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9425 - loss: 0.3963 - val_accuracy: 0.9495 - val_loss: 0.3620
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9444 - loss: 0.3720 - val_accuracy: 0.9495 - val_loss: 0.3518
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9451 - loss: 0.3609 - val_accuracy: 0.9461 - val_loss: 0.3501
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9493 - loss: 0.3392 - val_accuracy: 0.9515 - val_loss: 0.3353
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9515 - loss: 0.3286 - val_accuracy: 0.9536 - val_loss: 0.3198
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9498 - loss: 0.3257 - val_accuracy: 0.9556 - val_loss: 0.3114
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9460 - loss: 0.3325
# Test accuracy:0.9534

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers,models,regularizers
from tensorflow.keras.callbacks import EarlyStopping

(x_train,y_train),(x_test,y_test)=mnist.load_data()

x_train=x_train.astype("float32")/255.0
x_test=x_test.astype("float32")/255.0

x_train=x_train.reshape(-1,784)
x_test=x_test.reshape(-1,784)

y_train=to_categorical(y_train,10)
y_test=to_categorical(y_test,10)

def build_l2_model():
    model=models.Sequential([
        layers.Dense(64,activation='relu',input_shape=(784,),kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(64,activation='relu',kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(10,activation='softmax')
    ])
    return model

model_l2=build_l2_model()

model_l2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

earlystop = EarlyStopping(
    monitor='val_accuracy',
    patience=3,
    restore_best_weights=True
)



history=model_l2.fit(
    x_train,
    y_train,
    epochs=20,
    validation_split=0.2,
    batch_size=256,
    callbacks=[earlystop]
)

test_loss,test_acc=model_l2.evaluate(x_test,y_test)

print(f"Test accuracy:{test_acc:.4f}")
# Out:
# Epoch 1/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6807 - loss: 2.2388 - val_accuracy: 0.9141 - val_loss: 0.7777
# Epoch 2/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9079 - loss: 0.7392 - val_accuracy: 0.9221 - val_loss: 0.6074
# Epoch 3/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9162 - loss: 0.5993 - val_accuracy: 0.9249 - val_loss: 0.5336
# Epoch 4/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9243 - loss: 0.5370 - val_accuracy: 0.9319 - val_loss: 0.4916
# Epoch 5/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9281 - loss: 0.4981 - val_accuracy: 0.9362 - val_loss: 0.4714
# Epoch 6/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9286 - loss: 0.4763 - val_accuracy: 0.9388 - val_loss: 0.4412
# Epoch 7/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9354 - loss: 0.4487 - val_accuracy: 0.9411 - val_loss: 0.4287
# Epoch 8/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9345 - loss: 0.4361 - val_accuracy: 0.9440 - val_loss: 0.4159
# Epoch 9/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9383 - loss: 0.4197 - val_accuracy: 0.9456 - val_loss: 0.4035
# Epoch 10/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9438 - loss: 0.4064 - val_accuracy: 0.9463 - val_loss: 0.3912
# Epoch 11/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9457 - loss: 0.3931 - val_accuracy: 0.9481 - val_loss: 0.3800
# Epoch 12/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9476 - loss: 0.3858 - val_accuracy: 0.9503 - val_loss: 0.3724
# Epoch 13/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9483 - loss: 0.3750 - val_accuracy: 0.9498 - val_loss: 0.3759
# Epoch 14/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9489 - loss: 0.3674 - val_accuracy: 0.9536 - val_loss: 0.3531
# Epoch 15/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9501 - loss: 0.3642 - val_accuracy: 0.9535 - val_loss: 0.3495
# Epoch 16/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9513 - loss: 0.3523 - val_accuracy: 0.9509 - val_loss: 0.3475
# Epoch 17/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9514 - loss: 0.3507 - val_accuracy: 0.9562 - val_loss: 0.3399
# Epoch 18/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9538 - loss: 0.3441 - val_accuracy: 0.9528 - val_loss: 0.3382
# Epoch 19/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9527 - loss: 0.3395 - val_accuracy: 0.9528 - val_loss: 0.3333
# Epoch 20/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9537 - loss: 0.3354 - val_accuracy: 0.9575 - val_loss: 0.3188
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9490 - loss: 0.3430
# Test accuracy:0.9576

# %% [markdown]
# In the first experiment, a smaller batch size (32) and 10 epochs were used, giving 95.34% accuracy. In the second experiment, a larger batch size (256) and 20 epochs were used, resulting in slightly higher accuracy (95.76%). Larger batch size provides stable gradient updates, and more epochs allow better convergence.

# %% [markdown]
# data Augmentation

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False,
    vertical_flip=False
)

datagen.fit(x_train)

def build_l2_model():
    model = models.Sequential([
        layers.Flatten(input_shape=(28, 28, 1)),
        layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(10, activation='softmax')
    ])
    return model

model_l2 = build_l2_model()

model_l2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model_l2.fit(
    datagen.flow(x_train, y_train, batch_size=32),
    epochs=10,
    validation_data=(x_test, y_test),
    steps_per_epoch=len(x_train) // 32
)

test_loss, test_acc = model_l2.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 31s 16ms/step - accuracy: 0.6658 - loss: 1.7188 - val_accuracy: 0.9202 - val_loss: 0.7184
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.8716 - loss: 0.8431 - val_accuracy: 0.9424 - val_loss: 0.5807
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8876 - loss: 0.7312 - val_accuracy: 0.9393 - val_loss: 0.5361
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 42s 16ms/step - accuracy: 0.8955 - loss: 0.6720 - val_accuracy: 0.9460 - val_loss: 0.4830
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.9024 - loss: 0.6281 - val_accuracy: 0.9467 - val_loss: 0.4623
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.9043 - loss: 0.6000 - val_accuracy: 0.9333 - val_loss: 0.4937
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.9073 - loss: 0.5810 - val_accuracy: 0.9378 - val_loss: 0.4635
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.9060 - loss: 0.5724 - val_accuracy: 0.9456 - val_loss: 0.4297
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.9066 - loss: 0.5593 - val_accuracy: 0.9474 - val_loss: 0.4235
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.9084 - loss: 0.5505 - val_accuracy: 0.9513 - val_loss: 0.4055
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9415 - loss: 0.4323
# Test accuracy: 0.9513

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False,
    vertical_flip=False
)

datagen.fit(x_train)

def build_l2_model():
    model = models.Sequential([
        layers.Flatten(input_shape=(28, 28, 1)),
        layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(10, activation='softmax')
    ])
    return model

model_l2 = build_l2_model()

model_l2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model_l2.fit(
    datagen.flow(x_train, y_train, batch_size=32),
    epochs=20,
    validation_data=(x_test, y_test),
    steps_per_epoch=len(x_train) // 32
)

test_loss, test_acc = model_l2.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 32s 16ms/step - accuracy: 0.6640 - loss: 1.7067 - val_accuracy: 0.9195 - val_loss: 0.7120
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8703 - loss: 0.8418 - val_accuracy: 0.9346 - val_loss: 0.5947
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.8895 - loss: 0.7214 - val_accuracy: 0.9459 - val_loss: 0.5145
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.8942 - loss: 0.6728 - val_accuracy: 0.9461 - val_loss: 0.4781
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 40s 16ms/step - accuracy: 0.8961 - loss: 0.6358 - val_accuracy: 0.9468 - val_loss: 0.4642
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.9023 - loss: 0.6074 - val_accuracy: 0.9418 - val_loss: 0.4584
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.9049 - loss: 0.5820 - val_accuracy: 0.9402 - val_loss: 0.4516
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.9067 - loss: 0.5613 - val_accuracy: 0.9423 - val_loss: 0.4399
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.9054 - loss: 0.5587 - val_accuracy: 0.9483 - val_loss: 0.4175
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.9087 - loss: 0.5412 - val_accuracy: 0.9460 - val_loss: 0.4134
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.9068 - loss: 0.5414 - val_accuracy: 0.9558 - val_loss: 0.3788
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.9084 - loss: 0.5312 - val_accuracy: 0.9580 - val_loss: 0.3845
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.9094 - loss: 0.5233 - val_accuracy: 0.9471 - val_loss: 0.4052
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.9112 - loss: 0.5175 - val_accuracy: 0.9517 - val_loss: 0.3813
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.9092 - loss: 0.5230 - val_accuracy: 0.9537 - val_loss: 0.3876
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.9110 - loss: 0.5158 - val_accuracy: 0.9465 - val_loss: 0.3864
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.9105 - loss: 0.5087 - val_accuracy: 0.9427 - val_loss: 0.4073
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.9111 - loss: 0.5119 - val_accuracy: 0.9476 - val_loss: 0.3861
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.9122 - loss: 0.5038 - val_accuracy: 0.9478 - val_loss: 0.3833
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.9137 - loss: 0.4992 - val_accuracy: 0.9494 - val_loss: 0.3837
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9443 - loss: 0.4071
# Test accuracy: 0.9494

# %% [markdown]
# **Dataset Augmentation**

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False,
    vertical_flip=False
)

datagen.fit(x_train)

def build_l2_model():
    model = models.Sequential([
        layers.Flatten(input_shape=(28, 28, 1)),
        layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(10, activation='softmax')
    ])
    return model

model_l2 = build_l2_model()

model_l2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model_l2.fit(
    datagen.flow(x_train, y_train, batch_size=32),
    epochs=10,
    validation_data=(x_test, y_test),
    steps_per_epoch=len(x_train) // 32
)

test_loss, test_acc = model_l2.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 14ms/step - accuracy: 0.7775 - loss: 1.2218 - val_accuracy: 0.9163 - val_loss: 0.7133
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 15ms/step - accuracy: 0.8731 - loss: 0.8092 - val_accuracy: 0.9349 - val_loss: 0.5921
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.8908 - loss: 0.7153 - val_accuracy: 0.9342 - val_loss: 0.5487
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - accuracy: 0.8975 - loss: 0.6558 - val_accuracy: 0.9450 - val_loss: 0.4853
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 14ms/step - accuracy: 0.9004 - loss: 0.6229 - val_accuracy: 0.9360 - val_loss: 0.4905
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 14ms/step - accuracy: 0.9041 - loss: 0.5968 - val_accuracy: 0.9408 - val_loss: 0.4621
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 14ms/step - accuracy: 0.9046 - loss: 0.5800 - val_accuracy: 0.9443 - val_loss: 0.4481
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 14ms/step - accuracy: 0.9040 - loss: 0.5725 - val_accuracy: 0.9495 - val_loss: 0.4195
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.9049 - loss: 0.5609 - val_accuracy: 0.9398 - val_loss: 0.4454
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 15ms/step - accuracy: 0.9085 - loss: 0.5459 - val_accuracy: 0.9499 - val_loss: 0.4057
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9499 - loss: 0.4057
# Test accuracy: 0.9499

# %% [markdown]
# **Parameter sharing and tying**

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical

# Load MNIST
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

shared_dense = Dense(64, activation='relu')

input1 = Input(shape=(784,))
input2 = Input(shape=(784,))

# Apply SAME layer (parameter sharing)
encoded1 = shared_dense(input1)
encoded2 = shared_dense(input2)

# Merge
merged = Concatenate()([encoded1, encoded2])
output = Dense(10, activation='softmax')(merged)

model = Model(inputs=[input1, input2], outputs=output)

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit([x_train, x_train], y_train,
          epochs=5,
          batch_size=256,
          validation_split=0.2)

test_loss, test_acc = model.evaluate([x_test, x_test], y_test)
print("Test accuracy (Parameter Sharing):", test_acc)
# Out:
# Epoch 1/5
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8484 - loss: 0.5593 - val_accuracy: 0.9248 - val_loss: 0.2695
# Epoch 2/5
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9274 - loss: 0.2533 - val_accuracy: 0.9377 - val_loss: 0.2145
# Epoch 3/5
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9435 - loss: 0.1996 - val_accuracy: 0.9494 - val_loss: 0.1795
# Epoch 4/5
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9539 - loss: 0.1650 - val_accuracy: 0.9538 - val_loss: 0.1603
# Epoch 5/5
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9593 - loss: 0.1415 - val_accuracy: 0.9578 - val_loss: 0.1493
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9565 - loss: 0.1458
# Test accuracy (Parameter Sharing): 0.9564999938011169

# %% [markdown]
# **Adding noise to the inputs and outputs**

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers, models

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

noise_factor = 0.2
x_train_noisy = x_train + noise_factor * np.random.normal(
    loc=0.0, scale=1.0, size=x_train.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)

noise_ratio = 0.1
num_samples = int(noise_ratio * y_train.shape[0])

random_indices = np.random.choice(y_train.shape[0], num_samples, replace=False)

for idx in random_indices:
    random_label = np.random.randint(0, 10)
    y_train[idx] = to_categorical(random_label, 10)

def build_model():
    model = models.Sequential([
        layers.Dense(64, activation='relu', input_shape=(784,)),
        layers.Dense(64, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    return model

model = build_model()

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    x_train_noisy,
    y_train,
    epochs=20,
    batch_size=256,
    validation_split=0.2
)

test_loss, test_acc = model.evaluate(x_test, y_test)

print(f"Test accuracy: {test_acc:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7405 - loss: 1.0430 - val_accuracy: 0.8203 - val_loss: 0.8179
# Epoch 2/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8287 - loss: 0.7786 - val_accuracy: 0.8386 - val_loss: 0.7635
# Epoch 3/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8442 - loss: 0.7224 - val_accuracy: 0.8458 - val_loss: 0.7389
# Epoch 4/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8557 - loss: 0.6833 - val_accuracy: 0.8475 - val_loss: 0.7231
# Epoch 5/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8627 - loss: 0.6541 - val_accuracy: 0.8516 - val_loss: 0.7190
# Epoch 6/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8683 - loss: 0.6295 - val_accuracy: 0.8552 - val_loss: 0.7086
# Epoch 7/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8730 - loss: 0.6077 - val_accuracy: 0.8576 - val_loss: 0.7133
# Epoch 8/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8765 - loss: 0.5879 - val_accuracy: 0.8563 - val_loss: 0.7128
# Epoch 9/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8795 - loss: 0.5712 - val_accuracy: 0.8569 - val_loss: 0.7109
# Epoch 10/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8821 - loss: 0.5549 - val_accuracy: 0.8594 - val_loss: 0.7099
# Epoch 11/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8844 - loss: 0.5398 - val_accuracy: 0.8602 - val_loss: 0.7080
# Epoch 12/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8860 - loss: 0.5268 - val_accuracy: 0.8569 - val_loss: 0.7185
# Epoch 13/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8877 - loss: 0.5107 - val_accuracy: 0.8472 - val_loss: 0.7458
# Epoch 14/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8889 - loss: 0.4987 - val_accuracy: 0.8572 - val_loss: 0.7348
# Epoch 15/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8913 - loss: 0.4825 - val_accuracy: 0.8553 - val_loss: 0.7415
# Epoch 16/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8926 - loss: 0.4705 - val_accuracy: 0.8522 - val_loss: 0.7543
# Epoch 17/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8945 - loss: 0.4581 - val_accuracy: 0.8516 - val_loss: 0.7658
# Epoch 18/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8963 - loss: 0.4462 - val_accuracy: 0.8490 - val_loss: 0.7845
# Epoch 19/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8982 - loss: 0.4320 - val_accuracy: 0.8482 - val_loss: 0.7869
# Epoch 20/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8995 - loss: 0.4202 - val_accuracy: 0.8459 - val_loss: 0.7991
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8955 - loss: 0.5367
# Test accuracy: 0.8955

# %% [markdown]
# **Ensemble methods**

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers, models

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

y_train_cat = to_categorical(y_train, 10)
y_test_cat = to_categorical(y_test, 10)

model1 = models.Sequential([
    layers.Dense(64, activation='relu', input_shape=(784,)),
    layers.Dense(10, activation='softmax')
])

model1.compile(optimizer='adam',
               loss='categorical_crossentropy',
               metrics=['accuracy'])

model1.fit(x_train, y_train_cat,
           epochs=5, batch_size=256, verbose=0)

model2 = models.Sequential([
    layers.Dense(128, activation='relu', input_shape=(784,)),
    layers.Dense(10, activation='softmax')
])

model2.compile(optimizer='adam',
               loss='categorical_crossentropy',
               metrics=['accuracy'])

model2.fit(x_train, y_train_cat,
           epochs=5, batch_size=256, verbose=0)

model3 = models.Sequential([
    layers.Dense(128, activation='relu', input_shape=(784,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model3.compile(optimizer='adam',
               loss='categorical_crossentropy',
               metrics=['accuracy'])

model3.fit(x_train, y_train_cat,
           epochs=5, batch_size=256, verbose=0)

print("Model 1 Accuracy:", model1.evaluate(x_test, y_test_cat, verbose=0)[1])
print("Model 2 Accuracy:", model2.evaluate(x_test, y_test_cat, verbose=0)[1])
print("Model 3 Accuracy:", model3.evaluate(x_test, y_test_cat, verbose=0)[1])

pred1 = model1.predict(x_test)
pred2 = model2.predict(x_test)
pred3 = model3.predict(x_test)

ensemble_pred = (pred1 + pred2 + pred3) / 3

ensemble_classes = np.argmax(ensemble_pred, axis=1)

ensemble_accuracy = np.mean(ensemble_classes == y_test)

print("Ensemble Accuracy:", ensemble_accuracy)
# Out:
# Model 1 Accuracy: 0.958899974822998
# Model 2 Accuracy: 0.9713000059127808
# Model 3 Accuracy: 0.9706000089645386
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Ensemble Accuracy: 0.9718

# %% [markdown]
# **Dropouts**

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers, models

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

def build_model():
    model = models.Sequential([
        layers.Dense(64, activation='relu', input_shape=(784,)),
        layers.Dropout(0.3),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(10, activation='softmax')
    ])
    return model

model = build_model()

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

epochs = 20
batch_size = 256

history = model.fit(
    x_train,
    y_train,
    epochs=epochs,
    batch_size=batch_size,
    validation_split=0.2
)

test_loss, test_acc = model.evaluate(x_test, y_test)

print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7230 - loss: 0.8760 - val_accuracy: 0.9178 - val_loss: 0.2807
# Epoch 2/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8817 - loss: 0.3979 - val_accuracy: 0.9363 - val_loss: 0.2110
# Epoch 3/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9055 - loss: 0.3184 - val_accuracy: 0.9469 - val_loss: 0.1826
# Epoch 4/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9197 - loss: 0.2775 - val_accuracy: 0.9530 - val_loss: 0.1627
# Epoch 5/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9265 - loss: 0.2498 - val_accuracy: 0.9557 - val_loss: 0.1494
# Epoch 6/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9320 - loss: 0.2267 - val_accuracy: 0.9574 - val_loss: 0.1428
# Epoch 7/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9378 - loss: 0.2114 - val_accuracy: 0.9612 - val_loss: 0.1334
# Epoch 8/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9421 - loss: 0.1973 - val_accuracy: 0.9632 - val_loss: 0.1260
# Epoch 9/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9442 - loss: 0.1879 - val_accuracy: 0.9647 - val_loss: 0.1206
# Epoch 10/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9464 - loss: 0.1755 - val_accuracy: 0.9662 - val_loss: 0.1195
# Epoch 11/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9501 - loss: 0.1692 - val_accuracy: 0.9666 - val_loss: 0.1158
# Epoch 12/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9486 - loss: 0.1682 - val_accuracy: 0.9679 - val_loss: 0.1125
# Epoch 13/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9526 - loss: 0.1580 - val_accuracy: 0.9693 - val_loss: 0.1089
# Epoch 14/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9543 - loss: 0.1505 - val_accuracy: 0.9703 - val_loss: 0.1063
# Epoch 15/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9570 - loss: 0.1429 - val_accuracy: 0.9688 - val_loss: 0.1088
# Epoch 16/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9567 - loss: 0.1432 - val_accuracy: 0.9706 - val_loss: 0.1044
# Epoch 17/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9592 - loss: 0.1343 - val_accuracy: 0.9725 - val_loss: 0.1001
# Epoch 18/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9598 - loss: 0.1320 - val_accuracy: 0.9714 - val_loss: 0.0999
# Epoch 19/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9617 - loss: 0.1277 - val_accuracy: 0.9716 - val_loss: 0.0996
# Epoch 20/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9613 - loss: 0.1253 - val_accuracy: 0.9727 - val_loss: 0.0963
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9702 - loss: 0.0997
# Test accuracy: 0.9702
